# %%
## 중요사항 , 판다스 , 인식 불가

# %%
import datetime
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %%
stock_data = pd.read_excel('../index_Infomation_v0.1.xlsx')
stock_data['Date'] = pd.to_datetime(stock_data['Date'])
stock_data
# Out:
#            Date  nasdaq_Close  snp500_Close     DJI_Close  KOSPI_Close  \
# 0    2014-09-17   4562.189941   2001.569946  17156.849609      2062.61
# 1    2014-09-18   4593.430176   2011.359985  17265.990234      2047.74
# 2    2014-09-19   4579.790039   2010.400024  17279.740234      2053.82
# 3    2014-09-20   4579.790039   2010.400024  17279.740234      2053.82
# 4    2014-09-21   4579.790039   2010.400024  17279.740234      2053.82
# ...         ...           ...           ...           ...          ...
# 3570 2024-06-26  17805.160156   5477.899902  39127.800781      2792.05
# 3571 2024-06-27  17858.679688   5482.870117  39164.058594      2784.06
# 3572 2024-06-28  17732.599609   5460.479980  39118.859375      2797.82
# 3573 2024-06-29  17732.599609   5460.479980  39118.859375      2797.82
# 3574 2024-06-30  17732.599609   5460.479980  39118.859375      2797.82
#
#       samsung_PER  samsung_PBR  samsung_ROE  apple_PER  apple_PBR  ...  \
# 0            6.20         1.44     0.232258   3.538585   5.522882  ...
# 1            6.12         1.43     0.233660   3.545900   5.534299  ...
# 2            6.12         1.43     0.233660   3.516986   5.489171  ...
# 3            6.12         1.43     0.233660   3.516986   5.489171  ...
# 4            6.12         1.43     0.233660   3.516986   5.489171  ...
# ...           ...          ...          ...        ...        ...  ...
# 3570        38.15         1.56     0.040891  33.427232  52.171891  ...
# 3571        38.29         1.57     0.041003  33.560471  52.379846  ...
# 3572        38.24         1.57     0.041056  33.014975  51.528457  ...
# 3573        38.24         1.57     0.041056  33.014975  51.528457  ...
# 3574        38.24         1.57     0.041056  33.014975  51.528457  ...
#
#       중앙은행 기준금리  생산자물가지수  수입물가지수  소비자물가지수      수입      수출    경상수지  소비자심리지수  \
# 0          2.25   101.14  115.94    94.49  113.38  108.08  7418.7    108.3
# 1          2.25   101.14  115.94    94.49  113.38  108.08  7418.7    108.3
# 2          2.25   101.14  115.94    94.49  113.38  108.08  7418.7    108.3
# 3          2.25   101.14  115.94    94.49  113.38  108.08  7418.7    108.3
# 4          2.25   101.14  115.94    94.49  113.38  108.08  7418.7    108.3
# ...         ...      ...     ...      ...     ...     ...     ...      ...
# 3570       3.50   119.19  142.76   113.84  126.00  134.46  8922.5    100.9
# 3571       3.50   119.19  142.76   113.84  126.00  134.46  8922.5    100.9
# 3572       3.50   119.19  142.76   113.84  126.00  134.46  8922.5    100.9
# 3573       3.50   119.19  142.76   113.84  126.00  134.46  8922.5    100.9
# 3574       3.50   119.19  142.76   113.84  126.00  134.46  8922.5    100.9
#
#       기업경기실사지수  foreign_exchange_reserves
# 0           72                       3644
# 1           72                       3644
# 2           72                       3644
# 3           72                       3644
# 4           72                       3644
# ...        ...                        ...
# 3570        74                       4122
# 3571        74                       4122
# 3572        74                       4122
# 3573        74                       4122
# 3574        74                       4122
#
# [3575 rows x 42 columns]

# %%
compare1 = "samsung"
compare2 = "foreign_exchange_reserves"
compare2data = "foreign_exchange_reserves"

# %%
df = stock_data[['Date', f'{compare1}_Close', f'{compare2data}', 'dollar_to_won_Close']]
df
# Out:
#            Date  samsung_Close  foreign_exchange_reserves  dollar_to_won_Close
# 0    2014-09-17          24520                       3644          1034.900024
# 1    2014-09-18          24200                       3644          1033.599976
# 2    2014-09-19          24200                       3644          1042.599976
# 3    2014-09-20          24200                       3644          1042.599976
# 4    2014-09-21          24200                       3644          1042.599976
# ...         ...            ...                        ...                  ...
# 3570 2024-06-26          81300                       4122          1390.890015
# 3571 2024-06-27          81600                       4122          1393.380005
# 3572 2024-06-28          81500                       4122          1386.949951
# 3573 2024-06-29          81500                       4122          1386.949951
# 3574 2024-06-30          81500                       4122          1386.949951
#
# [3575 rows x 4 columns]

# %%
# 삼성전자 주식 그래프 그리기

plt.figure(figsize=(20, 5))
plt.plot(df['Date'], df[f'{compare1}_Close'], label=f'{compare1}')

plt.title(f'{compare1} Stock Price')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.grid(True)

plt.show()

# %%
# 데이터 타입 확인 
print(df['Date'].dtype)
print(df[f'{compare2data}'].dtype)
# Out:
# datetime64[ns]
# int64

# %%
# 경제지표 그래프 그리기

plt.figure(figsize=(20,5))
plt.plot(df['Date'], df[f'{compare2data}'], label=f'{compare2}', color = 'green')

plt.title(f'{compare2}')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.grid(True)

plt.show()

# %%
# 삼성 vs 외환보유액 그래프 그리기

plt.figure(figsize=(20,5))
plt.plot(df['Date'], df[f'{compare1}_Close'], label=f'{compare1}')
plt.plot(df['Date'], df[f'{compare2data}'], label=f'{compare2}', color='green')

plt.title(f'{compare1} vs {compare2}')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.grid(True)

plt.show()

# %%
# 0과 1 사이의 값으로 정규화
def normalize(df, column):
    return (df[column] - df[column].min()) / (df[column].max() - df[column].min())

# %%
compare1_normalize = normalize(df, f'{compare1}_Close')
compare2_normalize = normalize(df, f'{compare2data}')

# %%
# replace 쉼표 변경
df[f'{compare2data}'] = df[f'{compare2data}'].replace('[\$,]', '', regex=True).astype(float)
df['dollar_to_won_Close'] = df['dollar_to_won_Close'].replace('[\$,]', '', regex=True).astype(float)
df
# Out:
# C:\Users\4호실-8\AppData\Local\Temp\ipykernel_8620\2366179432.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'{compare2data}'] = df[f'{compare2data}'].replace('[\$,]', '', regex=True).astype(float)
# C:\Users\4호실-8\AppData\Local\Temp\ipykernel_8620\2366179432.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['dollar_to_won_Close'] = df['dollar_to_won_Close'].replace('[\$,]', '', regex=True).astype(float)
#            Date  samsung_Close  foreign_exchange_reserves  dollar_to_won_Close
# 0    2014-09-17          24520                     3644.0          1034.900024
# 1    2014-09-18          24200                     3644.0          1033.599976
# 2    2014-09-19          24200                     3644.0          1042.599976
# 3    2014-09-20          24200                     3644.0          1042.599976
# 4    2014-09-21          24200                     3644.0          1042.599976
# ...         ...            ...                        ...                  ...
# 3570 2024-06-26          81300                     4122.0          1390.890015
# 3571 2024-06-27          81600                     4122.0          1393.380005
# 3572 2024-06-28          81500                     4122.0          1386.949951
# 3573 2024-06-29          81500                     4122.0          1386.949951
# 3574 2024-06-30          81500                     4122.0          1386.949951
#
# [3575 rows x 4 columns]

# %%
compare1_normalize = normalize(df, f'{compare1}_Close')
compare2_normalize = normalize(df, f'{compare2data}')

# %%
# 정규화 적용 vs 그래프

plt.figure(figsize=(20, 5))
plt.plot(df['Date'], compare1_normalize, label=f'{compare1}')
plt.plot(df['Date'], compare2_normalize, label=f'{compare2}', color='green')

plt.title(f'{compare1} vs {compare2}')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.grid(True)


plt.show()

# %%
# 변동율 차이 비교
compare1_daily_change = df[f'{compare1}_Close'].pct_change()
compare2_daily_change = df[f'{compare2data}'].pct_change()

# %%
#그래프화
plt.figure(figsize=(20,5))
plt.plot(df['Date'], compare1_daily_change, label=f'{compare1}')
plt.plot(df['Date'], compare2_daily_change, label=f'{compare2}', color='green')
plt.ylim(-0.05, 0.05)

plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.grid(True)

plt.show()

# %%
# 정규화 데이터로 산점도 그래프
plt.figure(figsize=(20,5))
plt.scatter(compare1_normalize, compare2_normalize, alpha=0.05)

plt.title(f'{compare1} vs {compare2} scatter')
plt.xlabel(f'{compare1} stock price')
plt.ylabel(f'{compare2}')
plt.legend()
plt.grid(True)

plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# Calculate the correlation
correlation = df[f'{compare2data}'].corr(df[f'{compare1}_Close'])
print(f"Correlation between {compare2} and {compare1} Stock Price: {correlation:.2f}")
# Out:
# Correlation between foreign_exchange_reserves and samsung Stock Price: 0.89

# %%
import numpy as np
import statsmodels.api as sm
from sklearn.preprocessing import MinMaxScaler
from statsmodels.tsa.vector_ar.vecm import coint_johansen
from statsmodels.tsa.stattools import grangercausalitytests

stock_data = df
# 필요한 데이터만 가져오기
df = stock_data[['Date', f'{compare1}_Close', f'{compare2data}', 'dollar_to_won_Close']]
df['US_GDP_KRW'] = round(df[f'{compare2data}'] * df['dollar_to_won_Close'])
df.head(3)

def normalize_data(series):
    # MinMaxScaler를 사용하여 데이터를 -1과 1 사이로 정규화
    scaler = MinMaxScaler(feature_range=(-1, 1))
    return scaler.fit_transform(series.values.reshape(-1, 1))

def Regression(compare1, compare2data, compare2):
    # 데이터 정규화
    stock_data[f'{compare1}_Close_Normalized'] = normalize_data(stock_data[f'{compare1}_Close'])
    stock_data[f'{compare2data}_Normalized'] = normalize_data(stock_data[f'{compare2data}'])

    # 선형 회귀 분석
    X = stock_data[f'{compare1}_Close_Normalized']
    y = stock_data[f'{compare2data}_Normalized']
    X = sm.add_constant(X)  # 상수항 추가
    model = sm.OLS(y, X).fit()
    predictions = model.predict(X)

    # 회귀 분석 결과 출력
    print(model.summary())

    # 산점도 및 회귀선 그래프
    plt.scatter(stock_data[f'{compare2data}_Normalized'], stock_data[f'{compare1}_Close_Normalized'], label='Data points')
    plt.plot(stock_data[f'{compare2data}_Normalized'], predictions, color='red', label='Regression line')
    plt.xlabel(f'{compare2} (Normalized)')
    plt.ylabel(f'{compare1} (Normalized)')
    plt.legend()
    plt.show()

    
def rolling_correlation_and_granger_test(compare1, compare2data, compare2, window_size=30, max_lag=5, stock_data=stock_data):
    col1 = f'{compare1}_Close'
    col2 = compare2data

    # 날짜 인덱스 설정
    if not pd.api.types.is_datetime64_any_dtype(stock_data.index):
        stock_data.index = pd.to_datetime(stock_data['Date'])
        stock_data = stock_data.drop(columns=['Date'])

    # 롤링 상관관계 계산
    rolling_corr = stock_data[col1].rolling(window=window_size).corr(stock_data[col2]).dropna()

    # 무한 값과 NaN 값 제거
    rolling_corr = rolling_corr[~rolling_corr.isin([np.inf, -np.inf])].dropna()

    # 롤링 상관관계 그래프 그리기
    plt.figure(figsize=(10, 6))
    plt.plot(rolling_corr)
    plt.xlabel('Date')
    plt.ylabel('Rolling Correlation')
    plt.title(f'Dynamic Correlation between {col1} and {compare2}')
    plt.show()

    # 롤링 상관관계의 히스토그램 그리기
    plt.figure(figsize=(10, 6))
    plt.hist(rolling_corr, bins=30, edgecolor='k')
    plt.xlabel('Rolling Correlation')
    plt.ylabel('Frequency')
    plt.title(f'Histogram of Rolling Correlations between {col1} and {compare2}')
    plt.show()

    # 그랜저 인과성 테스트
    granger_test_result = grangercausalitytests(stock_data[[col1, col2]], max_lag, verbose=True)

    return rolling_corr, granger_test_result

def Granger(compare1, compare2data, compare2, stock_data=stock_data):
    if f'{compare1}_Close' not in stock_data.columns or compare2data not in stock_data.columns:
        raise KeyError(f"Columns {compare1}_Close and/or {compare2data} not found in the provided DataFrame")
    
    max_lag = 2
    result1 = grangercausalitytests(stock_data[[f'{compare1}_Close', compare2data]], max_lag, verbose=True)
    result2 = coint_johansen(stock_data[[f'{compare1}_Close', compare2data]], det_order=-1, k_ar_diff=1)
    
    return result1, result2.lr1, result2.cvt

def everything(compare1, compare2data, compare2):
    Granger(compare1, compare2data, compare2)
    Regression(compare1, compare2data, compare2)
    rolling_correlation_and_granger_test(compare1, compare2data, compare2)
everything(compare1, compare2data, compare2)
# Out:
# c:\Anaconda3\envs\myenv\Lib\site-packages\statsmodels\tsa\stattools.py:1545: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
# C:\Users\4호실-8\AppData\Local\Temp\ipykernel_8620\1335162435.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stock_data[f'{compare1}_Close_Normalized'] = normalize_data(stock_data[f'{compare1}_Close'])
# C:\Users\4호실-8\AppData\Local\Temp\ipykernel_8620\1335162435.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   stock_data[f'{compare2data}_Normalized'] = normalize_data(stock_data[f'{compare2data}'])
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.2757  , p=0.2588  , df_denom=3571, df_num=1
# ssr based chi2 test:   chi2=1.2767  , p=0.2585  , df=1
# likelihood ratio test: chi2=1.2765  , p=0.2585  , df=1
# parameter F test:         F=1.2757  , p=0.2588  , df_denom=3571, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.8119  , p=0.4441  , df_denom=3568, df_num=2
# ssr based chi2 test:   chi2=1.6261  , p=0.4435  , df=2
# likelihood ratio test: chi2=1.6258  , p=0.4436  , df=2
# parameter F test:         F=0.8119  , p=0.4441  , df_denom=3568, df_num=2
#                                      OLS Regression Results
# ================================================================================================
# Dep. Variable:     foreign_exchange_reserves_Normalized   R-squared:                       0.794
# Model:                                              OLS   Adj. R-squared:                  0.794
# Method:                                   Least Squares   F-statistic:                 1.381e+04
# Date:                                  Thu, 08 Aug 2024   Prob (F-statistic):               0.00
# Time:                                          16:54:30   Log-Likelihood:                -95.934
# No. Observations:                                  3575   AIC:                             195.9
# Df Residuals:                                      3573   BIC:                             208.2
# Df Model:                                             1
# Covariance Type:                              nonrobust
# ============================================================================================
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# const                       -0.0707      0.004    -16.537      0.000      -0.079      -0.062
# samsung_Close_Normalized     0.9407      0.008    117.519      0.000       0.925       0.956
# ==============================================================================
# Omnibus:                        8.535   Durbin-Watson:                   0.008
# Prob(Omnibus):                  0.014   Jarque-Bera (JB):                9.187
# Skew:                          -0.076   Prob(JB):                       0.0101
# Kurtosis:                       3.196   Cond. No.                         1.96
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.2757  , p=0.2588  , df_denom=3571, df_num=1
# ssr based chi2 test:   chi2=1.2767  , p=0.2585  , df=1
# likelihood ratio test: chi2=1.2765  , p=0.2585  , df=1
# parameter F test:         F=1.2757  , p=0.2588  , df_denom=3571, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.8119  , p=0.4441  , df_denom=3568, df_num=2
# ssr based chi2 test:   chi2=1.6261  , p=0.4435  , df=2
# likelihood ratio test: chi2=1.6258  , p=0.4436  , df=2
# parameter F test:         F=0.8119  , p=0.4441  , df_denom=3568, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.6130  , p=0.1842  , df_denom=3565, df_num=3
# ssr based chi2 test:   chi2=4.8486  , p=0.1832  , df=3
# likelihood ratio test: chi2=4.8453  , p=0.1835  , df=3
# parameter F test:         F=1.6130  , p=0.1842  , df_denom=3565, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.2272  , p=0.2970  , df_denom=3562, df_num=4
# ssr based chi2 test:   chi2=4.9212  , p=0.2955  , df=4
# likelihood ratio test: chi2=4.9178  , p=0.2958  , df=4
# parameter F test:         F=1.2272  , p=0.2970  , df_denom=3562, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.4072  , p=0.2183  , df_denom=3559, df_num=5
# ssr based chi2 test:   chi2=7.0580  , p=0.2164  , df=5
# likelihood ratio test: chi2=7.0510  , p=0.2169  , df=5
# parameter F test:         F=1.4072  , p=0.2183  , df_denom=3559, df_num=5
# c:\Anaconda3\envs\myenv\Lib\site-packages\statsmodels\tsa\stattools.py:1545: FutureWarning: verbose is deprecated since functions should not print results
#   warnings.warn(
