# %%
import datetime
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %%
ko_info = pd.read_excel('../index_Infomation_v0.1.xlsx')

# %%
ko_info.head()
# Out:
#          Date  nasdaq_Close  snp500_Close   DJI_Close  KOSPI_Close  \
# 0  2014-11-01    4630.74023    2018.05004  17390.5195      1964.43
# 1  2014-11-02    4630.74023    2018.05004  17390.5195      1964.43
# 2  2014-11-03    4638.91015    2017.81005  17366.2402      1952.97
# 3  2014-11-04    4623.64013    2012.09997  17383.8398      1935.19
# 4  2014-11-05    4620.72021    2023.56994  17484.5292      1931.43
#
#    samsung_PER  samsung_PBR  samsung_ROE  apple_PER  apple_PBR  ...  \
# 0         6.29         1.47     0.233704   3.794397   5.922144  ...
# 1         6.29         1.47     0.233704   3.794397   5.922144  ...
# 2         6.24         1.45     0.232372   3.843583   5.998912  ...
# 3         6.15         1.43     0.232520   3.815476   5.955043  ...
# 4         6.08         1.42     0.233553   3.824611   5.969301  ...
#
#    중앙은행 기준금리  생산자물가지수  수입물가지수  소비자물가지수      수입      수출     경상수지  소비자심리지수  \
# 0        2.0   100.12   113.7   94.015  105.99  107.37  10582.7    103.3
# 1        2.0   100.12   113.7   94.015  105.99  107.37  10582.7    103.3
# 2        2.0   100.12   113.7   94.015  105.99  107.37  10582.7    103.3
# 3        2.0   100.12   113.7   94.015  105.99  107.37  10582.7    103.3
# 4        2.0   100.12   113.7   94.015  105.99  107.37  10582.7    103.3
#
#    기업경기실사지수  foreign_exchange_reserves
# 0        71                      3,631
# 1        71                      3,631
# 2        71                      3,631
# 3        71                      3,631
# 4        71                      3,631
#
# [5 rows x 41 columns]

# %% [markdown]
# ## apple_Close, oil_Close 비교

# %%
apple_close = ko_info[['Date', 'apple_Close']]
oil_close = ko_info[['Date', 'oil_Close']]

apple_close
# Out:
#             Date  apple_Close
# 0     2014-11-01    27.000000
# 1     2014-11-02    27.000000
# 2     2014-11-03    27.350000
# 3     2014-11-04    27.150000
# 4     2014-11-05    27.215000
# ...          ...          ...
# 3525  2024-06-26   213.250000
# 3526  2024-06-27   214.100006
# 3527  2024-06-28   210.619995
# 3528  2024-06-29   210.619995
# 3529  2024-06-30   210.619995
#
# [3530 rows x 2 columns]

# %%
oil_close
# Out:
#             Date  oil_Close
# 0     2014-11-01  85.860001
# 1     2014-11-02  85.860001
# 2     2014-11-03  84.779999
# 3     2014-11-04  82.820000
# 4     2014-11-05  82.949997
# ...          ...        ...
# 3525  2024-06-26  85.250000
# 3526  2024-06-27  86.389999
# 3527  2024-06-28  86.410004
# 3528  2024-06-29  86.410004
# 3529  2024-06-30  86.410004
#
# [3530 rows x 2 columns]

# %%
import warnings

# %%
apple_close.loc[:, 'Date'] = pd.to_datetime(apple_close['Date'])

plt.figure(figsize=(20, 5))
plt.plot(apple_close['Date'], apple_close['apple_Close'], label='Apple Electornics', color='red')
plt.title('Apple Electornics Stock Price')
plt.xlabel('Date')
plt.ylabel('Closing Price (Dollar)')

ax = plt.gca()
ax.xaxis.set_major_locator(mdates.YearLocator(1))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))

plt.legend()
plt.grid(True)
plt.show()

# %%
oil_close['Date']
# Out:
# 0       2014-11-01
# 1       2014-11-02
# 2       2014-11-03
# 3       2014-11-04
# 4       2014-11-05
#            ...
# 3525    2024-06-26
# 3526    2024-06-27
# 3527    2024-06-28
# 3528    2024-06-29
# 3529    2024-06-30
# Name: Date, Length: 3530, dtype: object

# %%
oil_close.loc[:, 'Date'] = pd.to_datetime(oil_close['Date'])
# Plotting the data
plt.figure(figsize=(20, 5))
plt.plot(oil_close['Date'], oil_close['oil_Close'], label='Oil Closing Price', color='goldenrod')
plt.title('Oil Closing Prices')
plt.xlabel('Date')
plt.ylabel('Oil Closing Price (USD)')

ax = plt.gca()
ax.xaxis.set_major_locator(mdates.YearLocator(1))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))

plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

oil_close.loc[:, 'Date'] = pd.to_datetime(oil_close['Date'])
apple_close.loc[:, 'Date'] = pd.to_datetime(apple_close['Date'])

plt.figure(figsize=(20, 5))
plt.plot(oil_close['Date'], oil_close['oil_Close'], label='Oil Closing Price', color='goldenrod')
plt.plot(apple_close['Date'], apple_close['apple_Close'], label='Apple Electronics', color='red')
plt.title('Oil Closing Prices and Apple Electronics Stock Price')
plt.xlabel('Date')
plt.ylabel('Price (USD)')

ax = plt.gca()
ax.xaxis.set_major_locator(mdates.YearLocator(1))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))

plt.legend()
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# 사본 생성 후 Date 컬럼을 datetime 형식으로 변환
oil_close_copy = oil_close.copy()
apple_close_copy = apple_close.copy()

oil_close_copy['Date'] = pd.to_datetime(oil_close_copy['Date'])
apple_close_copy['Date'] = pd.to_datetime(apple_close_copy['Date'])

# 일일 변동률 계산
oil_close_copy['Oil Change %'] = oil_close_copy['oil_Close'].pct_change() * 100
apple_close_copy['Apple Change %'] = apple_close_copy['apple_Close'].pct_change() * 100

# Date를 기준으로 데이터프레임 병합
merged_df = pd.merge(oil_close_copy[['Date', 'Oil Change %']], apple_close_copy[['Date', 'Apple Change %']], on='Date', how='inner')

# 변동률 (일일 퍼센트 변동) 그래프 그리기
fig, ax1 = plt.subplots(figsize=(20, 7))

ax1.plot(merged_df['Date'], merged_df['Oil Change %'], label='Oil Price Change %', color='goldenrod')
ax1.set_xlabel('Date')
ax1.set_ylabel('Oil Price Change %', color='goldenrod')
ax1.tick_params(axis='y', labelcolor='goldenrod')

ax1.xaxis.set_major_locator(mdates.YearLocator(1))
ax1.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))

ax2 = ax1.twinx()
ax2.plot(merged_df['Date'], merged_df['Apple Change %'], label='Apple Stock Price Change %', color='red')
ax2.set_ylabel('Apple Stock Price Change %', color='red')
ax2.tick_params(axis='y', labelcolor='red')

plt.title('Oil Price and Apple Electronics Stock Price Volatility')
fig.tight_layout()
plt.grid(True)

fig.legend(loc="upper left", bbox_to_anchor=(0.1,0.9), bbox_transform=ax1.transAxes)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 사본 생성 후 Date 컬럼을 datetime 형식으로 변환
oil_close_copy = oil_close.copy()
apple_close_copy = apple_close.copy()

oil_close_copy['Date'] = pd.to_datetime(oil_close_copy['Date'])
apple_close_copy['Date'] = pd.to_datetime(apple_close_copy['Date'])

# Date를 기준으로 데이터프레임 병합
merged_df = pd.merge(oil_close_copy[['Date', 'oil_Close']], apple_close_copy[['Date', 'apple_Close']], on='Date', how='inner')

# 산점도 그래프 
plt.figure(figsize=(10, 7))
plt.scatter(merged_df['oil_Close'], merged_df['apple_Close'], alpha=0.2)
plt.title('Correlation between Oil Price and Apple Electronics Stock Price', color='black')
plt.xlabel('Oil Price (USD)', color='black')
plt.ylabel('Apple Stock Price (USD)', color='black')
plt.grid(True)
plt.xticks(color='black')
plt.yticks(color='black')
plt.gca().set_facecolor('white')  # 배경색 흰색
plt.show()

# %%
import pandas as pd
import numpy as np

oil_close_copy = oil_close.copy()
apple_close_copy = apple_close.copy()
oil_close_copy['Date'] = pd.to_datetime(oil_close_copy['Date'])
apple_close_copy['Date'] = pd.to_datetime(apple_close_copy['Date'])

# 0 값을 가지는 행을 제외한 후 일일 변동률 계산
oil_close_copy = oil_close_copy[oil_close_copy['oil_Close'] != 0]
apple_close_copy = apple_close_copy[apple_close_copy['apple_Close'] != 0]

oil_close_copy['Oil Change %'] = oil_close_copy['oil_Close'].pct_change() * 100
apple_close_copy['Apple Change %'] = apple_close_copy['apple_Close'].pct_change() * 100

# Date를 기준으로 데이터프레임 병합
merged_df = pd.merge(oil_close_copy[['Date', 'Oil Change %']], apple_close_copy[['Date', 'Apple Change %']], on='Date', how='inner')

# 결측치 및 무한대 값 제거
merged_df = merged_df.replace([np.inf, -np.inf], np.nan).dropna()

# 애플 주식과 유가의 상관계수 계산
correlation = merged_df['Oil Change %'].corr(merged_df['Apple Change %'])
print(f"Correlation between Oil Price and Apple Stock Price: {correlation:.2f}")
# Out:
# Correlation between Oil Price and Apple Stock Price: 0.16
